# %%
import pandas as pd
df=pd.read_csv('results.csv')

# %%
df
# Out:
#                                               JobTitle  \
# 0                Accountant II (Senior Budget Officer)
# 1                                    Senior Accountant
# 2                                    SENIOR ACCOUNTANT
# 3    Senior Accountant - Friends of the Children - ...
# 4                       Senior Construction Accountant
# ..                                                 ...
# 102                         Senior Assurance Associate
# 103        Senior Analyst, Domestic Tax, Federal Focus
# 104                    Sr. Tax Analyst - International
# 105                               Senior Audit Manager
# 106                               Senior Tax Associate
#
#                                       Company             Location  \
# 0    City of Charlotte and Mecklenburg County        Charlotte, NC
# 1                             Childress Klein        Charlotte, NC
# 2                             CABARRUS COUNTY  Cabarrus County, NC
# ...
